# %%
# 1 soo jiido libraries ka
import numpy as np 
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
# 2 soo jiido file ka
CSV_PATH = "clean_house_l5_dataset.csv"
df = pd.read_csv(CSV_PATH)
print(df.head())
print(f"waa shape ka datasetka", df.shape )
# Out:
#    Size_sqft  Bedrooms  Bathrooms  YearBuilt     Price  Location_City  \
# 0   1.030281 -1.463643   0.088986  -1.279342  812100.0              1
# 1  -0.482463 -1.463643   1.347506   1.326476  547000.0              1
# 2   0.468877  0.007430  -1.169534  -1.339942  693700.0              1
# 3   1.079817  0.742966   1.347506  -0.915740  848300.0              1
# 4   0.788954  1.478502  -1.169534   0.962873  806000.0              0
#
#    Location_Rural  Location_Suburb  HouseAge  Rooms_per_1000sqft  \
# 0               0                0  1.279342           -1.061465
# 1               0                0 -1.326476           -0.265637
# 2               0                0  1.339942           -0.689547
# 3               0                0  0.915740           -0.199111
# 4               0                1 -0.962873           -0.311002
#
#    Size_per_Bedroom  Is_City   LogPrice
# 0          3.123085        1  13.607380
# 1          1.309520        1  13.212206
# ...

# %%
# 3 features ka x ka reeb labelska,  y waa labelska
x = df.drop(columns=["Price", "LogPrice"])
y = df["Price"]

# %%
# 4 data u kala saar trining iyo test 80/20 
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
print(f"Train shape: {x_train.shape}, Test shape: {x_test.shape}")
# Out:
# Train shape: (79, 11), Test shape: (20, 11)

# %%
# training linear and predict
lr = LinearRegression()

# %%
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
#trainig random forest and predict
rf = RandomForestRegressor(n_estimators=100, random_state=42)

# %%
rf.fit(x_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
# prediction 
lr_pred = lr.predict(x_test)
rf_pred = rf.predict(x_test)

# %%
print(f"linear regeression {lr_pred}")
print(f"Random Forest {rf_pred}")
# Out:
# linear regeression [656754.66720779 822634.7173445  188637.49473079 594040.9378655
#  609615.22485083 411139.21882379 444365.96225017 727107.31998415
#  718486.32165982 825315.58832644 299971.0381155  486275.95067698
#  420030.94370326 552711.25630098 679903.86858088 747845.50808667
#  379820.32605756 565493.59852803 258460.20166531 537055.55071361]
# Random Forest [789031. 821977. 290899. 557028. 538756. 297368. 396774. 724944. 777862.
#  832261. 311571. 551531. 393837. 551299. 711626. 779024. 302785. 540015.
#  330577. 545878.]

# %%
#fuction kuso saara metrics
def metrics(name, y, y_predict):  
  r2 = r2_score(y, y_predict)    
  mae = mean_absolute_error(y, y_predict)  
  mse = mean_squared_error(y, y_predict) 
  rmse = np.sqrt(mse)           

  #soo saar metrics kana saar format float
  print(f"predicting of {name}")
  print(f"R2: {r2:.3f}")
  print(f"MAE: {mae:,.0f}")
  print(f"MSE: {mse:,.0f}")
  print(f"RMSE: {rmse:,.0f}")

# %%
#soo saar natiijada metrics
metrics("Linear Regression", y_test, lr_pred)  
metrics("Random Forest", y_test, rf_pred)
# Out:
# predicting of Linear Regression
# R2: 0.848
# MAE: 63,086
# MSE: 5,718,940,941
# RMSE: 75,624
# predicting of Random Forest
# R2: 0.859
# MAE: 52,524
# MSE: 5,283,317,455
# RMSE: 72,686

# %%
# single row predicton (sanity check)  size_sqft
i = 0    
x_one_df = x_test.iloc[[i]]
y_true = y_test[i]

p_lr_one = float(lr.predict(x_one_df)[0])
p_rf_one = float(rf.predict(x_one_df)[0])

#natiijada size_sqft
print("\n size_sqft single-row sanity check:")
print(f"Actual size sqft: {y_true:,.0f}") 
print(f"LR Pred: {p_lr_one:,.0f}")  
print(f"RF Pred: {p_rf_one:,.0f}")
# Out:
#  size_sqft single-row sanity check:
# Actual size sqft: 812,100
# LR Pred: 656,755
# RF Pred: 789,031

# %%
# single row predicton (sanity check)  price
i = 4  
x_one_df = x_test.iloc[[i]]
y_true = y_test[i]

p_lr_one = float(lr.predict(x_one_df)[0])
p_rf_one = float(rf.predict(x_one_df)[0])

#natiijada price ka
print("\n price single-row sanity check:")
print(f"Actual price: ${y_true:,.0f}") 
print(f"LR Pred: ${p_lr_one:,.0f}")  
print(f"RF Pred: ${p_rf_one:,.0f}")
# Out:
#  price single-row sanity check:
# Actual price: $806,000
# LR Pred: $609,615
# RF Pred: $538,756

# %%
# single row predicton (sanity check)  HouseAge
i = 8
x_one_df = x_test.iloc[[i]]
y_true = y_test.iloc[i]

p_lr_one = float(lr.predict(x_one_df)[0])
p_rf_one = float(rf.predict(x_one_df)[0])

# #natiijada HouseAge ka
print("\n HouseAge single-row sanity check")
print(f" actual HouseAge:  {y_true:}")
print(f" LR prded : {p_lr_one:} ")
print(f" RF pred : {p_rf_one:} ")
# Out:
#  HouseAge single-row sanity check
#  actual HouseAge:  654200.0
#  LR prded : 718486.321659815
#  RF pred : 777862.0

# %%
# single row predicton (sanity check)  size_per_bedroom
i = 10
x_one_df = x_test.iloc[[i]]
y_true = y_test.iloc[i]

p_lr_one = float(lr.predict(x_one_df)[0])
p_rf_one = float(rf.predict(x_one_df)[0])

# #natiijada size_per_bedroom ka
print("\n size_per_bedroom single-row sanity check")
print(f" actual size_per_bedroom:  {y_true:}")
print(f" LR prded : {p_lr_one:} ")
print(f" RF pred : {p_rf_one:} ")
# Out:
#  size_per_bedroom single-row sanity check
#  actual size_per_bedroom:  366000.0
#  LR prded : 299971.0381155011
#  RF pred : 311571.0
