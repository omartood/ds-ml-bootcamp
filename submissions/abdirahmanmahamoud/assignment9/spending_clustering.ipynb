# %%
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_score, davies_bouldin_score

# %%
CSV_PATH = "../../../dataset/spending_l9_dataset.csv"
df = pd.read_csv(CSV_PATH)
print(df.head().isnull().sum())
# Out:
# CustomerID         0
# Age                0
# Income_$           0
# SpendingScore      0
# VisitsPerMonth     0
# OnlinePurchases    0
# Gender             0
# Region             0
# dtype: int64

# %%
FEATURES = ["Income_$", "SpendingScore"]
X = df[FEATURES]

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
print(X_scaled)
# Out:
# [[-0.62783049  0.72998073]
#  [-0.89031514  1.07359091]
#  [-0.92312573  1.11176982]
#  [-0.89031514  0.53908619]
#  [-0.95593631  1.11176982]
#  [-0.98874689  0.80633855]
#  [-1.18561038  1.41720108]
#  [-0.85750456  1.035412  ]
#  [-0.95593631  1.4935589 ]
#  [-0.75907282  0.84451746]
#  [-0.98874689  0.88269636]
#  [-1.25123155  1.07359091]
#  [-0.95593631  1.30266436]
#  [-0.66064107  1.14994872]
#  [-0.98874689  0.61544401]
#  [-1.08717864  1.035412  ]
#  [-1.11998922  0.99723309]
#  [-1.11998922  0.84451746]
#  [-0.98874689  0.76815964]
#  [-1.11998922  1.4935589 ]
#  [-0.69345165  0.84451746]
#  [-0.98874689  0.72998073]
#  [-0.92312573  1.18812763]
#  [-0.69345165  1.035412  ]
#  [-0.69345165  0.95905418]
#  [-0.98874689  1.22630654]
#  [-0.89031514  1.11176982]
#  [-0.82469398  1.07359091]
#  [-0.95593631  1.26448545]
#  [-1.21842096  1.07359091]
#  [-0.82469398  0.80633855]
#  [-0.7918834   0.88269636]
#  [-0.85750456  0.80633855]
#  [-1.08717864  1.035412  ]
#  [-0.95593631  0.65362291]
#  [-1.02155747  0.42454946]
#  [-0.98874689  0.99723309]
#  [-0.72626223  0.5772651 ]
#  [-0.69345165  0.38637055]
#  [-0.82469398  1.07359091]
#  [-0.85750456  0.76815964]
#  [-0.82469398  1.11176982]
#  [-0.95593631  0.80633855]
#  [-0.95593631  0.65362291]
#  [-1.05436805  0.61544401]
#  [-0.95593631  0.80633855]
#  [-0.56220932  0.88269636]
#  [-0.7918834   0.72998073]
#  [-0.98874689  0.88269636]
#  [-1.02155747  0.50090728]
#  [ 0.25805523  0.53908619]
#  [ 0.1268129   0.34819165]
#  [-0.2341035  -0.22449198]
#  [ 0.25805523 -0.79717561]
#  [ 0.42210814 -0.18631307]
#  [ 0.1268129  -0.14813417]
#  [ 0.15962348 -0.79717561]
#  [ 0.55335047 -0.14813417]
#  [-0.13567176 -0.22449198]
#  [-0.20129292 -0.37720762]
#  [-0.00442943  0.00458147]
#  [-0.13567176  0.11911819]
#  [ 0.52053988 -0.3008498 ]
#  [ 0.25805523 -0.10995526]
#  [-0.03724001 -0.33902871]
#  [ 0.02838115 -0.37720762]
#  [ 0.91426687 -0.14813417]
#  [ 0.02838115 -0.03359744]
#  [-0.03724001 -0.3008498 ]
#  [ 0.25805523 -0.7589967 ]
#  [ 0.35648697  0.00458147]
#  [ 0.22524465 -0.60628107]
#  [-0.07005059 -0.14813417]
#  [-0.13567176  0.31001274]
#  [ 0.32367639 -0.18631307]
#  [ 0.15962348 -0.49174434]
#  [ 1.43923618  0.69180182]
#  [ 1.63609967  0.88269636]
#  [ 1.60328909  0.84451746]
#  [ 1.34080444  1.035412  ]
#  [ 1.767342    0.46272837]
#  [ 1.767342    0.53908619]
#  [ 1.767342    0.31001274]
#  [ 1.50485735  0.92087527]
#  [ 1.50485735  0.76815964]
#  [ 1.24237269  0.65362291]
#  [ 1.767342    0.61544401]
#  [ 0.97988803  0.65362291]
#  [ 1.43923618  0.5772651 ]
#  [ 1.47204676  0.72998073]
#  [ 1.767342    0.69180182]
#  [ 1.53766793  1.11176982]
#  [ 1.30799385  0.84451746]
#  [ 1.17675153  0.61544401]
#  [ 1.37361502  0.65362291]
#  [ 1.57047851  1.07359091]
#  [ 1.57047851  0.88269636]
#  [ 1.50485735  0.84451746]
#  [ 1.37361502  0.95905418]
#  [ 1.50485735  1.14994872]
#  [ 1.80015258  0.50090728]
#  [ 1.27518327  0.61544401]
#  [ 1.57047851  0.38637055]
#  [ 1.96420549  0.88269636]
#  [ 1.70172084  0.69180182]
#  [ 1.43923618  0.61544401]
#  [ 1.73453142  0.61544401]
#  [ 1.34080444  0.95905418]
#  [ 1.57047851  0.76815964]
#  [ 1.96420549  0.65362291]
#  [ 2.06263724  1.07359091]
#  [ 1.11113036  0.53908619]
#  [ 1.73453142  0.50090728]
#  [ 2.06263724  1.37902218]]

# %%
for k in range(1, 11):
    km = KMeans(n_clusters=k, n_init="auto", random_state=42)
    km.fit(X_scaled)
    print(f"k={k} → SSE={km.inertia_:.2f}")
# Out:
# k=1 → SSE=400.00
# k=2 → SSE=199.70
# k=3 → SSE=79.37
# k=4 → SSE=21.37
# k=5 → SSE=19.09
# k=6 → SSE=15.65
# k=7 → SSE=14.48
# k=8 → SSE=13.81
# k=9 → SSE=12.94
# k=10 → SSE=11.52

# %%
K = 4
kmeans = KMeans(n_clusters=K, n_init="auto", random_state=42)
labels = kmeans.fit_predict(X_scaled)

df["Cluster"] = labels.astype(int)
print(df['Cluster'])
# Out:
# 0      2
# 1      2
# 2      2
# 3      2
# 4      2
#       ..
# 195    3
# 196    3
# 197    3
# 198    3
# 199    3
# Name: Cluster, Length: 200, dtype: int64

# %%
sil = silhouette_score(X_scaled, labels)
dbi = davies_bouldin_score(X_scaled, labels)
print(f"Silhouette Score : {sil:.3f} (closer to +1 is better)")
print(f"Davies–Bouldin   : {dbi:.3f} (lower is better)")
# Out:
# === METRICS ===
# Silhouette Score : 0.729 (closer to +1 is better)
# Davies–Bouldin   : 0.387 (lower is better)

# %%
centers_scaled = kmeans.cluster_centers_
centers_original = scaler.inverse_transform(centers_scaled)

centers_df = pd.DataFrame(centers_original, columns=FEATURES)
centers_df.index.name = "Cluster"
print(centers_df.round(2))
# Out:
#          Income_$  SpendingScore
# Cluster
# 0           56.32          53.58
# 1           28.92          19.60
# 2           24.14          83.10
# 3           99.16          79.24

# %%
sample_idx = [0, 54, 112]
sanity = df.loc[sample_idx, FEATURES + ["Cluster"]]
print(sanity)
# Out:
#      Income_$  SpendingScore  Cluster
# 0          33             78        2
# 54         65             54        0
# 112        26             18        1

# %%
OUT_PATH = "spending_labeled_clusters.csv"
df.to_csv(OUT_PATH, index=False)
