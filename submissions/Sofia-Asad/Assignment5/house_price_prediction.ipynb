# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
df = pd.read_csv("clean_house_l5_dataset.csv")

# %%
x = df.drop(columns=["Price", "LogPrice"])
y = df["Price"]

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=42)

# %%
model = LinearRegression()
rf = RandomForestRegressor(n_estimators=100, random_state=42)

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
rf.fit(x_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
lr_pred = model.predict(x_test)

# %%
rf_pred = rf.predict(x_test)

# %%
mae = mean_absolute_error (y_test, lr_pred,)
mse= mean_squared_error (y_test, lr_pred)
r2 = r2_score(y_test, lr_pred)

# %%
print(f"Mean Absolute Erro (MAE): {mae}") 
print(f"Mean Squared Error (MSE): {mse}") 
print(f"R-Squared (R2): {r2}")
# Out:
# Mean Absolute Erro (MAE): 63085.83804860744
# Mean Squared Error (MSE): 5718940940.596759
# R-Squared (R2): 0.8478474731443675

# %%
mae = mean_absolute_error (y_test, rf_pred)
mse= mean_squared_error (y_test, rf_pred)
r2 = r2_score(y_test, rf_pred)

# %%
print(f"Mean Absolute Erro (MAE): {mae}") 
print(f"Mean Squared Error (MSE): {mse}") 
print(f"R-Squared (R2): {r2}")
# Out:
# Mean Absolute Erro (MAE): 52523.85
# Mean Squared Error (MSE): 5283317454.95
# R-Squared (R2): 0.859437243835704

# %%
i = 2
x_one_df = x_test.iloc[[i]]
y_true   = y_test.iloc[i]

# %%
p_lr_one = float(model.predict(x_one_df)[0])
p_rf_one = float(rf.predict(x_one_df)[0])

# %%
print("\nSingle-row sanity check:")
print(f"  Actual Price: ${y_true:,.0f}")
print(f"  LR Pred     : ${p_lr_one:,.0f}")
print(f"  RF Pred     : ${p_rf_one:,.0f}")
# Out:
# Single-row sanity check:
#   Actual Price: $292,500
#   LR Pred     : $188,637
#   RF Pred     : $290,899

# %%
i = 3
x_one_df = x_test.iloc[[i]]
y_true   = y_test.iloc[i]

# %%
p_lr_one = float(model.predict(x_one_df)[0])
p_rf_one = float(rf.predict(x_one_df)[0])

# %%
print("\nSingle-row sanity check:")
print(f"  Actual Price: ${y_true:,.0f}")
print(f"  LR Pred     : ${p_lr_one:,.0f}")
print(f"  RF Pred     : ${p_rf_one:,.0f}")
# Out:
# Single-row sanity check:
#   Actual Price: $554,800
#   LR Pred     : $594,041
#   RF Pred     : $557,028

# %%
i = 4
x_one_df = x_test.iloc[[i]]
y_true   = y_test.iloc[i]

# %%
p_lr_one = float(model.predict(x_one_df)[0])
p_rf_one = float(rf.predict(x_one_df)[0])

# %%
print("\nSingle-row sanity check:")
print(f"  Actual Price: ${y_true:,.0f}")
print(f"  LR Pred     : ${p_lr_one:,.0f}")
print(f"  RF Pred     : ${p_rf_one:,.0f}")
# Out:
# Single-row sanity check:
#   Actual Price: $535,300
#   LR Pred     : $609,615
#   RF Pred     : $538,756
